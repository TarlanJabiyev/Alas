# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_diabetes
from sklearn.ensemble import RandomForestRegressor
from boruta import BorutaPy

# %%
X, y = load_diabetes(return_X_y=True, as_frame=True)

# %%
X
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019907 -0.017646
# 1   -0.039493 -0.068332 -0.092204
# 2   -0.002592  0.002861 -0.025930
# 3    0.034309  0.022688 -0.009362
# 4   -0.002592 -0.031988 -0.046641
# ..        ...       ...       ...
# 437 -0.002592  0.031193  0.007207
# 438  0.034309 -0.018114  0.044485
# 439 -0.011080 -0.046883  0.015491
# 440  0.026560  0.044529 -0.025930
# 441 -0.039493 -0.004222  0.003064
#
# [442 rows x 10 columns]

# %% [markdown]
# ## Boruta alqoritması ilə dəyişənlərin seçilməsi

# %%
model = RandomForestRegressor(n_estimators=100, max_depth=5, random_state=42)
model
# Out:
# RandomForestRegressor(max_depth=5, random_state=42)

# %%
feat_selector = BorutaPy(
    verbose=2,
    estimator=model,
    n_estimators='auto',
    max_iter=10  
)
feat_selector
# Out:
# BorutaPy(estimator=RandomForestRegressor(max_depth=5, random_state=42),
#          max_iter=10, n_estimators='auto', verbose=2)

# %% [markdown]
# ## Seçilən dəyişənlər

# %%
feat_selector.fit(np.array(X), np.array(y))
# Out:
# Iteration: 	1 / 10
# Confirmed: 	0
# Tentative: 	10
# Rejected: 	0
# Iteration: 	2 / 10
# Confirmed: 	0
# Tentative: 	10
# Rejected: 	0
# Iteration: 	3 / 10
# Confirmed: 	0
# Tentative: 	10
# Rejected: 	0
# Iteration: 	4 / 10
# Confirmed: 	0
# Tentative: 	10
# Rejected: 	0
# Iteration: 	5 / 10
# Confirmed: 	0
# Tentative: 	10
# Rejected: 	0
# Iteration: 	6 / 10
# Confirmed: 	0
# Tentative: 	10
# Rejected: 	0
# Iteration: 	7 / 10
# Confirmed: 	0
# Tentative: 	10
# Rejected: 	0
# Iteration: 	8 / 10
# Confirmed: 	4
# Tentative: 	3
# Rejected: 	3
# Iteration: 	9 / 10
# Confirmed: 	4
# Tentative: 	3
# Rejected: 	3
#
#
# BorutaPy finished running.
#
# Iteration: 	10 / 10
# Confirmed: 	4
# Tentative: 	0
# Rejected: 	6
# BorutaPy(estimator=RandomForestRegressor(max_depth=5, n_estimators=74,
#                                          random_state=RandomState(MT19937) at 0x104D29140),
#          max_iter=10, n_estimators='auto',
#          random_state=RandomState(MT19937) at 0x104D29140, verbose=2)

# %%
feat_selector.support_
# Out:
# array([False, False,  True,  True, False, False, False, False,  True,
#         True])
