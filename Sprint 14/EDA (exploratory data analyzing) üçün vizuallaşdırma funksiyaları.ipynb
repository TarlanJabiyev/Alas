# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("gapminder.csv")
dataset.head()
# Out:
#                country  year  infant_mortality  life_expectancy  fertility  \
# 0              Albania  1960            115.40            62.87       6.19
# 1              Algeria  1960            148.20            47.50       7.65
# 2               Angola  1960            208.00            35.98       7.32
# 3  Antigua and Barbuda  1960               NaN            62.97       4.43
# 4            Argentina  1960             59.87            65.39       3.11
#
#    population           gdp continent           region
# 0   1636054.0           NaN    Europe  Southern Europe
# 1  11124892.0  1.382815e+10    Africa  Northern Africa
# 2   5270844.0           NaN    Africa    Middle Africa
# 3     54681.0           NaN  Americas        Caribbean
# 4  20619075.0  1.083223e+11  Americas    South America

# %%
dataset.describe(include='all')
# Out:
#         country         year  infant_mortality  life_expectancy     fertility  \
# count     10545  10545.00000       9092.000000     10545.000000  10358.000000
# unique      185          NaN               NaN              NaN           NaN
# top     Albania          NaN               NaN              NaN           NaN
# freq         57          NaN               NaN              NaN           NaN
# mean        NaN   1988.00000         55.308619        64.811623      4.083521
# std         NaN     16.45273         47.728055        10.672495      2.027320
# min         NaN   1960.00000          1.500000        13.200000      0.840000
# 25%         NaN   1974.00000         16.000000        57.500000      2.200000
# 50%         NaN   1988.00000         41.500000        67.540000      3.750000
# 75%         NaN   2002.00000         85.100000        73.000000      6.000000
# max         NaN   2016.00000        276.900000        83.900000      9.220000
#
# ...

# %%
dataset.isnull().sum()
# Out:
# country                0
# year                   0
# infant_mortality    1453
# life_expectancy        0
# fertility            187
# population           185
# gdp                 2972
# continent              0
# region                 0
# dtype: int64

# %%
dataset.nunique()
# Out:
# country               185
# year                   57
# infant_mortality     1761
# life_expectancy      3095
# fertility             752
# population          10352
# gdp                  7562
# continent               5
# region                 22
# dtype: int64

# %%
sns.heatmap(dataset.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# %%
sns.pairplot(dataset, diag_kind="kde")

# %%
import missingno as msno

# %%
msno.matrix(dataset)
plt.show()

# %%
msno.heatmap(dataset)
plt.show()

# %%
from ydata_profiling import ProfileReport
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %%
profile = ProfileReport(dataset, title="pandas_profiling_report", explorative=True)
profile.to_file("pandas_profiling_report.html")

# %%
import sweetviz as sv

# %%
report = sv.analyze(dataset)
report.show_html("sweetviz_report.html")

# %%
import dtale

# %%
dtale.show(dataset)
